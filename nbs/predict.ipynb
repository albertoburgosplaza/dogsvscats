# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False

# %%
from dogsvscats.predict import predict_image

# %%
predict_image("dog.jpg")
# Out:
# {'label': 'dog', 'idx_label': tensor(1), 'score': 0.9978415966033936}

# %%
predict_image("cat.jpg")
# Out:
# {'label': 'cat', 'idx_label': tensor(0), 'score': 0.9997696280479431}
